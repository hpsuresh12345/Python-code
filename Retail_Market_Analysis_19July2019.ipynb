# %% [markdown]
# # Import necessary Packages

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import mlxtend as ml
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity='all'

# %% [markdown]
# # Read input file and display head, tail and info

# %%
df=pd.read_excel('Online_Retail.xlsx')
df.head()
df.tail()
df.info()
df.describe()
df.Country.nunique()
df.Country.unique()
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 0 2010-12-01 08:45:00       3.75     12583.0  France
# 1 2010-12-01 08:45:00       3.75     12583.0  France
# 2 2010-12-01 08:45:00       3.75     12583.0  France
# 3 2010-12-01 08:45:00       0.85     12583.0  France
# 4 2010-12-01 08:45:00       0.65     12583.0  France
#      InvoiceNo StockCode                      Description  Quantity  \
# 8552    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 8553    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# ...

# %% [markdown]
# # remove additional spaces,remove NA values,remove cancelled orders

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %% [markdown]
# # Creation of Basket

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

def create_basket(country_filter):
    basket = (df[df['Country'] == country_filter]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
    return basket

# %% [markdown]
# # Pandas profiling report

# %%
eda_report=pandas_profiling.ProfileReport(df)
eda_report.to_file("Retail_Market_19July2019_EDA_report.html")

# %% [markdown]
# # Selected France Online data for the Market Basket analysis

# %%
country_filter = "France"
basket_french = create_basket("France")
basket_sets = basket_french.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
basket_sets.shape
# Out:
# (392, 1562)

# %% [markdown]
# # find rules which have at least 5% support level

# %%
frequent_items=apriori(basket_sets, min_support = 0.05, use_colnames=True)
frequent_items
frequent_items.head()
frequent_items.tail()
# Out:
#       support                                           itemsets
# 0    0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1    0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2    0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3    0.094388                         (ALARM CLOCK BAKELIKE RED)
# 4    0.068878                       (ASSORTED COLOUR MINI CASES)
# 5    0.081633                     (BAKING SET 9 PIECE RETROSPOT)
# 6    0.051020                            (BLUE HARMONICA IN BOX)
# 7    0.068878                      (CHARLOTTE BAG APPLES DESIGN)
# 8    0.066327                  (CHARLOTTE BAG DOLLY GIRL DESIGN)
# 9    0.058673                      (CHARLOTTE BAG PINK POLKADOT)
# 10   0.051020                      (CHILDREN'S APRON DOLLY GIRL)
# 11   0.066327                  (CHILDRENS APRON SPACEBOY DESIGN)
# 12   0.071429                     (CHILDRENS CUTLERY DOLLY GIRL)
# ...

# %% [markdown]
# # build rules with minimum lift of 1

# %%
rules = association_rules(frequent_items, metric="lift", min_threshold=1.2)
rules.head()
# Out:
#                     antecedents                   consequents  \
# 0  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 1   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 2  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)
# 3    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)
# 4    (ALARM CLOCK BAKELIKE RED)   (ALARM CLOCK BAKELIKE PINK)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.096939            0.102041  0.073980    0.763158  7.478947
# 1            0.102041            0.096939  0.073980    0.725000  7.478947
# 2            0.096939            0.094388  0.079082    0.815789  8.642959
# 3            0.094388            0.096939  0.079082    0.837838  8.642959
# 4            0.094388            0.102041  0.073980    0.783784  7.681081
#
#    leverage  conviction
# 0  0.064088    3.791383
# 1  0.064088    3.283859
# 2  0.069932    4.916181
# 3  0.069932    5.568878
# ...

# %% [markdown]
# # Top 10 rules with highest support

# %%
rules.sort_values('support',ascending = False).head(10)
# Out:
#                              antecedents  \
# 66         (SET/6 RED SPOTTY PAPER CUPS)
# 67       (SET/6 RED SPOTTY PAPER PLATES)
# 52    (PLASTERS IN TIN WOODLAND ANIMALS)
# 53            (PLASTERS IN TIN SPACEBOY)
# 65       (SET/6 RED SPOTTY PAPER PLATES)
# 44    (PLASTERS IN TIN WOODLAND ANIMALS)
# 45       (PLASTERS IN TIN CIRCUS PARADE)
# 62  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 63         (SET/6 RED SPOTTY PAPER CUPS)
# 64  (SET/20 RED RETROSPOT PAPER NAPKINS)
#
#                              consequents  antecedent support  \
# 66       (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 67         (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 52            (PLASTERS IN TIN SPACEBOY)            0.170918
# 53    (PLASTERS IN TIN WOODLAND ANIMALS)            0.137755
# 65  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 44       (PLASTERS IN TIN CIRCUS PARADE)            0.170918
# 45    (PLASTERS IN TIN WOODLAND ANIMALS)            0.168367
# ...

# %% [markdown]
# # Top 10 rules with highest confidence

# %%
rules.sort_values('lift',ascending = False).head(10)
# Out:
#                                           antecedents  \
# 39                       (PACK OF 6 SKULL PAPER CUPS)
# 38                     (PACK OF 6 SKULL PAPER PLATES)
# 9                      (CHILDRENS CUTLERY DOLLY GIRL)
# 8                        (CHILDRENS CUTLERY SPACEBOY)
# 71                         (ALARM CLOCK BAKELIKE RED)
# 70  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 72                       (ALARM CLOCK BAKELIKE GREEN)
# 69  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 3                          (ALARM CLOCK BAKELIKE RED)
# 2                        (ALARM CLOCK BAKELIKE GREEN)
#
#                                           consequents  antecedent support  \
# 39                     (PACK OF 6 SKULL PAPER PLATES)            0.063776
# 38                       (PACK OF 6 SKULL PAPER CUPS)            0.056122
# 9                        (CHILDRENS CUTLERY SPACEBOY)            0.071429
# ...

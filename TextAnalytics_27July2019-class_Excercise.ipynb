# %%
# !pip install nltk

# %% [markdown]
# # Tokenize word

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
import csv 
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hpsur\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
sampleString="Hello World"
print(sampleString)
timeToday = "04,July,2018"
print(timeToday)
# Out:
# Hello World
# 04,July,2018

# %%
from nltk.tokenize import sent_tokenize
text = "I love the spaCy library. I can’t remember the last time I didn’t use it when I was working on an NLP project. It is just that useful. tate-of-the-art computation speed."
tokenized_text=sent_tokenize(text)
print(tokenized_text)
# Out:
# ['I love the spaCy library.', 'I can’t remember the last time I didn’t use it when I was working on an NLP project.', 'It is just that useful.', 'tate-of-the-art computation speed.']

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print (tokenized_word)
# Out:
# ['I', 'love', 'the', 'spaCy', 'library', '.', 'I', 'can', '’', 't', 'remember', 'the', 'last', 'time', 'I', 'didn', '’', 't', 'use', 'it', 'when', 'I', 'was', 'working', 'on', 'an', 'NLP', 'project', '.', 'It', 'is', 'just', 'that', 'useful', '.', 'tate-of-the-art', 'computation', 'speed', '.']

# %% [markdown]
# # Frequency distribution of Tokenzied Words

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 30 samples and 39 outcomes>

# %%
fdist.most_common(2)
# Out:
# [('I', 4), ('.', 4)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative = False)
plt.show()

# %% [markdown]
# # Removing stop words

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hpsur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
tokenized_sent = tokenized_word
# Out:
# {'off', 'those', 'himself', 'am', 'what', 'are', 'have', 'through', 'nor', 'after', 'again', 'both', 'will', 'the', 'herself', "wouldn't", 'shan', 're', 'very', "couldn't", 'him', 'own', 'being', 'hasn', 'in', 'by', "you've", 'or', 'don', 'each', 'is', 'at', 'did', 'where', 'until', 'most', 'couldn', 'ours', 'once', 'now', 'few', 'yours', 'about', 'his', "mightn't", 's', 'into', 'their', 'weren', 'not', 'y', 'between', 'there', 'having', 'd', 'shouldn', "aren't", 'these', "you'll", "hasn't", 'whom', "you're", "it's", 'too', 'your', 'has', 'its', "isn't", 'ourselves', 'then', "she's", 'mustn', 'our', 'with', 'which', 'here', 'that', 'aren', "mustn't", 'them', 'who', 'were', 't', 'we', 'and', 'up', 'out', 'do', 'of', 'o', 'itself', 'she', "needn't", 'he', "don't", 'it', "doesn't", 'than', 'this', 'under', 'myself', 'from', 'any', 'for', 'more', 'but', "weren't", 'if', 'a', 'to', 'such', 'so', 'before', 'themselves', 'needn', "shouldn't", 'as', "that'll", 'on', 'doesn', 'can', "wasn't",
# ...

# %%
filtered_sent=[]
for w in tokenized_sent:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokenized_sent)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['I', 'love', 'the', 'spaCy', 'library', '.', 'I', 'can', '’', 't', 'remember', 'the', 'last', 'time', 'I', 'didn', '’', 't', 'use', 'it', 'when', 'I', 'was', 'working', 'on', 'an', 'NLP', 'project', '.', 'It', 'is', 'just', 'that', 'useful', '.', 'tate-of-the-art', 'computation', 'speed', '.']
# Filterd Sentence: ['I', 'love', 'spaCy', 'library', '.', 'I', '’', 'remember', 'last', 'time', 'I', '’', 'use', 'I', 'working', 'NLP', 'project', '.', 'It', 'useful', '.', 'tate-of-the-art', 'computation', 'speed', '.']

# %% [markdown]
# # Stemming words

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()

# %%
stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['I', 'love', 'spaCy', 'library', '.', 'I', '’', 'remember', 'last', 'time', 'I', '’', 'use', 'I', 'working', 'NLP', 'project', '.', 'It', 'useful', '.', 'tate-of-the-art', 'computation', 'speed', '.']
# Stemmed Sentence: ['I', 'love', 'spaci', 'librari', '.', 'I', '’', 'rememb', 'last', 'time', 'I', '’', 'use', 'I', 'work', 'nlp', 'project', '.', 'It', 'use', '.', 'tate-of-the-art', 'comput', 'speed', '.']

# %% [markdown]
# # Lexicon Normalization
# # performing stemming and Lemmatization

# %%
import nltk
nltk.download('wordnet')

from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

word = "flying"
print("Lemmatized Word:",lem.lemmatize(word,"v"))
print("Stemmed Word:",stem.stem(word))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hpsur\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# Lemmatized Word: fly
# Stemmed Word: fli

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

sent = "Albert Einstein was born in Ulm, Germany in 1879."
tokens=nltk.word_tokenize(sent)
print(tokens)
nltk.pos_tag(tokens)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hpsur\AppData\Roaming\nltk_data...
# ['Albert', 'Einstein', 'was', 'born', 'in', 'Ulm', ',', 'Germany', 'in', '1879', '.']
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [('Albert', 'NNP'),
#  ('Einstein', 'NNP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('in', 'IN'),
#  ('Ulm', 'NNP'),
#  (',', ','),
#  ('Germany', 'NNP'),
#  ('in', 'IN'),
#  ('1879', 'CD'),
#  ('.', '.')]

# %%
samplestring2="India got it's independence in 1947.However,it is not yet clear,the progress of nation compared to china."
print(samplestring2)
# Out:
# India got it's independence in 1947.However,it is not yet clear,the progress of nation compared to china.

# %%
para="India got it's independence in 1947.However,it is not yet clear,the progress of nation compared to china."
sent = para.split('.')
sent
# Out:
# ["India got it's independence in 1947",
#  'However,it is not yet clear,the progress of nation compared to china',
#  '']

# %%
for India in para:
    for sent in para:
        print(sent.split())
# Out:
# ['I']
# ['n']
# ['d']
# ['i']
# ['a']
# []
# ['g']
# ['o']
# ['t']
# []
# ['i']
# ['t']
# ["'"]
# ['s']
# []
# ['i']
# ['n']
# ['d']
# ['e']
# ['p']
# ['e']
# ['n']
# ['d']
# ['e']
# ['n']
# ['c']
# ['e']
# []
# ['i']
# ['n']
# []
# ['1']
# ['9']
# ['4']
# ['7']
# ['.']
# ['H']
# ['o']
# ['w']
# ['e']
# ['v']
# ['e']
# ['r']
# [',']
# ['i']
# ['t']
# []
# ['i']
# ['s']
# []
# ['n']
# ['o']
# ['t']
# []
# ['y']
# ['e']
# ['t']
# []
# ['c']
# ['l']
# ['e']
# ['a']
# ['r']
# [',']
# ['t']
# ['h']
# ['e']
# []
# ['p']
# ['r']
# ['o']
# ['g']
# ['r']
# ['e']
# ['s']
# ['s']
# []
# ['o']
# ['f']
# []
# ['n']
# ['a']
# ['t']
# ['i']
# ['o']
# ['n']
# []
# ['c']
# ['o']
# ['m']
# ['p']
# ['a']
# ['r']
# ['e']
# ['d']
# []
# ['t']
# ['o']
# []
# ['c']
# ['h']
# ['i']
# ['n']
# ['a']
# ['.']
# ['I']
# ['n']
# ['d']
# ['i']
# ['a']
# []
# ['g']
# ['o']
# ['t']
# []
# ['i']
# ['t']
# ["'"]
# ['s']
# []
# ['i']
# ['n']
# ['d']
# ['e']
# ['p']
# ['e']
# ['n']
# ['d']
# ['e']
# ['n']
# ['c']
# ...

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
sent_tolenize_list=sent_tokenize(text)
len(sent_tolenize_list)
print(sent_tolenize_list)
# Out:
# ['I love the spaCy library.', 'I can’t remember the last time I didn’t use it when I was working on an NLP project.', 'It is just that useful.', 'tate-of-the-art computation speed.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hpsur\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
lst=['A','B','A','C','D']
dict = {}
for element in lst:
    if element in dict:
        dict[element]=dict[element]+1
    else:
        dict[element]=1
dict
# Out:
# {'A': 2, 'B': 1, 'C': 1, 'D': 1}

# %%
word_freq={}
str="This is A Good Sentence On good topic of This"
tokens=str.split()
print(tokens)
tokens_low=[]
for token in tokens:
     tokens_low.append(token.lower())
tokens_low
# Out:
# ['This', 'is', 'A', 'Good', 'Sentence', 'On', 'good', 'topic', 'of', 'This']
# ['this', 'is', 'a', 'good', 'sentence', 'on', 'good', 'topic', 'of', 'this']

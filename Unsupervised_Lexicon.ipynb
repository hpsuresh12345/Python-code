# %%
data=open("TweetSent.csv").readlines()

# %%
data[0:3]
# Out:
# ['Tweet,Category\n',
#  'Not Available,negative\n',
#  'IOS 9 App Transport Security. Mm need to check if my 3rd party network pod supports it http://t.co/fmtcfUAdgj,neutral\n']

# %%
for record in data[0:3]:
    print(record.split('|'))
# Out:
# ['Tweet,Category\n']
# ['Not Available,negative\n']
# ['IOS 9 App Transport Security. Mm need to check if my 3rd party network pod supports it http://t.co/fmtcfUAdgj,neutral\n']

# %%
word_list=[]
print(data)
word_list=[]
print("Word_list")
print(word_list)
print("Stripped records")
for record in data:
    print("record")
    print(record)
    tokens=record.split()
    print("Tokens")
    print(tokens)
    for word in words:
        words.append(word.lower())
        word_list.append(record.split())
        print("Word list")
        print(word_list)
# Out:
# ['Tweet,Category\n', 'Not Available,negative\n', 'IOS 9 App Transport Security. Mm need to check if my 3rd party network pod supports it http://t.co/fmtcfUAdgj,neutral\n', '"Mar if you have an iOS device, you should download our app too: http://t.co/gl3tn2uDnD",neutral\n', '@jimmie_vanagon my phone does not run on latest IOS which may account for problem the other day .. time it was replaced,negative\n', "Not sure how to start your publication on iOS? We'll be live helping with ask me anything sessions today and Friday http://t.co/KPqqGjjh3x,positive\n", '"Two Dollar Tuesday is here with Forklift 2, QuickKey for iOS and Suite for Pages for just $1.99 today:   http://t.co/BNMFOEACw5",neutral\n', '"If you\'re not already signed up to test my iOS game, nows your chance! https://t.co/eZhIU6EDpQ",neutral\n', '"YouTube Gaming Officially Launches On Web, Android, iOS On August 26: YouTube is finally going to r... http://t.co/qbhyA3kaWP #webseries",neutral\n', 'YouTube Gaming Launches Tomorrow with iOS and Android Apps to Go Head-to-Head with Twitch http://t.co/yZOATToeJC #ios #game,neutral\n', "@astrill Yashan from BBC @bbcchinese the VPN access on IOS may be limited during China's military parade? Any chance to have a chat on that?,neutral\n", "Parkrun app for iOS downloaded Where have you been before ?Great app easier access of info &amp; ready for Saturday's run http://t.co/ZyOFhZeRIO,positive\n", '"Today @YouTubeGaming launches, with apps for iOS and Android devices in the US and UK, here is what you need to know http://t.co/Kf8DgnHX9b",positive\n', 'Got a project you want to work on? Need help with Swift? Need an excuse to hang with iOS devs on a Sat? Hang with us! http://t.co/pUWsKbDfWe,positive\n', '"Met with iOS Developer today. We may have a ""go"". 8-)",positive\n', '#CrossSkyHigh is going IOS #saturday. For now try this http://t.co/Jrc6ktK9rT #indiedev @GamerRTer @ShoutGamers http://t.co/bkWUjKEmju,positive\n', "What's the best way to get audio recordings from a 3rd party app off of an iOS device? Jailbreaking isn't an option.,positive\n", "Five Great Free Apps and Games for iOS - August 27th Edition:  It's that time of the week again... http://t.co/QGkrIrKI28 #News #LCHBuzz,positive\n", '"@clayrussell @Nostradamion looks interesting but I\'ve ALWAYS ended up back on iOS keyboard, always glitches with iOS 8/9 3rd party ones",neutral\n', '"See news through the eyes of real people &amp; be your own reporter with Fresco 2.0 for iOS, coming September 8th! http://t.co/IfLPLqqsmy",positive\n', "Siri knows all about #Apple's iOS event on the 9th. #GiveUsAHint http://t.co/sHmTw46ELR,positive\n", '"Who\'s ready for 0.12.1 Build 12 Tomorrow, Might be the last build till it come to iOS !",positive\n', '"@facebook As I\'ve been on FB for many years, I have a few hundred photo albums, but only the 1st 200 appear in the IOS app. Is that right?",positive\n', '@Yurt try beat mp3 it may be on android i have it on ios and its fairly decent,positive\n', '@androidcentral Even though there are other differences in the IOS features this still may make people lean a little more towards Apple.,positive\n', 'Huawei Watch Pre-Order Suggests Android Wear Coming To iOS: IPhone owners who want to use Android Wear may soo... http://t.co/JQhdN5tCUV,neutral\n', 'SpeedeNews: Rumor: Android Wear will soon work with iOS - Android Wear may be very close to working with iOS. That... http://t.co/pq0g0Z3eOy,neutral\n', '"Over here in NW near 11th &amp; Rhode Island, if you need a Lyft let me know !  Download the LYFT app for IOS or Android !",neutral\n', '@NarisDRIFT @T_Dogg_94ebooks I wish that CustomFolderIcons worked on iOS 5.1.1 and it was received on December 11th.,neutral\n', "So today i checked my old iPod 4th gen which is on iOS 6.1.6 and it can't be upgraded further and i randomly open twitter,neutral\n", '"@_tomcc @bartwerf please stop walking and work !! You have more than one month of late --"" The update was annonced the 29 of july, IOS wait!",nega ...
# Word_list
# []
# Stripped records
# record
# Tweet,Category
#
# Tokens
# ['Tweet,Category']
# record
# Not Available,negative
#
# Tokens
# ['Not', 'Available,negative']
# record
# IOS 9 App Transport Security. Mm need to check if my 3rd party network pod supports it http://t.co/fmtcfUAdgj,neutral
#
# Tokens
# ['IOS', '9', 'App', 'Transport', 'Security.', 'Mm', 'need', 'to', 'check', 'if', 'my', '3rd', 'party', 'network', 'pod', 'supports', 'it', 'http://t.co/fmtcfUAdgj,neutral']
# record
# "Mar if you have an iOS device, you should download our app too: http://t.co/gl3tn2uDnD",neutral
#
# Tokens
# ['"Mar', 'if', 'you', 'have', 'an', 'iOS', 'device,', 'you', 'should', 'download', 'our', 'app', 'too:', 'http://t.co/gl3tn2uDnD",neutral']
# record
# @jimmie_vanagon my phone does not run on latest IOS which may account for problem the other day .. time it was replaced,negative
#
# Tokens
# ['@jimmie_vanagon', 'my', 'phone', 'does', 'not', 'run', 'on', 'latest', 'IOS', 'which', 'may', 'account', 'for', 'problem', 'the', 'other', 'day', '..', 'time', 'it', 'was', 'replaced,negative']
# record
# Not sure how to start your publication on iOS? We'll be live helping with ask me anything sessions today and Friday http://t.co/KPqqGjjh3x,positive
#
# Tokens
# ['Not', 'sure', 'how', 'to', 'start', 'your', 'publication', 'on', 'iOS?', "We'll", 'be', 'live', 'helping', 'with', 'ask', 'me', 'anything', 'sessions', 'today', 'and', 'Friday', 'http://t.co/KPqqGjjh3x,positive']
# record
# "Two Dollar Tuesday is here with Forklift 2, QuickKey for iOS and Suite for Pages for just $1.99 today:   http://t.co/BNMFOEACw5",neutral
#
# Tokens
# ['"Two', 'Dollar', 'Tuesday', 'is', 'here', 'with', 'Forklift', '2,', 'QuickKey', 'for', 'iOS', 'and', 'Suite', 'for', 'Pages', 'for', 'just', '$1.99', 'today:', 'http://t.co/BNMFOEACw5",neutral']
# record
# "If you're not already signed up to test my iOS game, nows your chance! https://t.co/eZhIU6EDpQ",neutral
#
# Tokens
# ['"If', "you're", 'not', 'already', 'signed', 'up', 'to', 'test', 'my', 'iOS', 'game,', 'nows', 'your', 'chance!', 'https://t.co/eZhIU6EDpQ",neutral']
# record
# "YouTube Gaming Officially Launches On Web, Android, iOS On August 26: YouTube is finally going to r... http://t.co/qbhyA3kaWP #webseries",neutral
#
# Tokens
# ['"YouTube', 'Gaming', 'Officially', 'Launches', 'On', 'Web,', 'Android,', 'iOS', 'On', 'August', '26:', 'YouTube', 'is', 'finally', 'going', 'to', 'r...', 'http://t.co/qbhyA3kaWP', '#webseries",neutral']
# record
# YouTube Gaming Launches Tomorrow with iOS and Android Apps to Go Head-to-Head with Twitch http://t.co/yZOATToeJC #ios #game,neutral
#
# Tokens
# ['YouTube', 'Gaming', 'Launches', 'Tomorrow', 'with', 'iOS', 'and', 'Android', 'Apps', 'to', 'Go', 'Head-to-Head', 'with', 'Twitch', 'http://t.co/yZOATToeJC', '#ios', '#game,neutral']
# record
# @astrill Yashan from BBC @bbcchinese the VPN access on IOS may be limited during China's military parade? Any chance to have a chat on that?,neutral
#
# Tokens
# ['@astrill', 'Yashan', 'from', 'BBC', '@bbcchinese', 'the', 'VPN', 'access', 'on', 'IOS', 'may', 'be', 'limited', 'during', "China's", 'military', 'parade?', 'Any', 'chance', 'to', 'have', 'a', 'chat', 'on', 'that?,neutral']
# record
# Parkrun app for iOS downloaded Where have you been before ?Great app easier access of info &amp; ready for Saturday's run http://t.co/ZyOFhZeRIO,positive
#
# Tokens
# ['Parkrun', 'app', 'for', 'iOS', 'downloaded', 'Where', 'have', 'you', 'been', 'before', '?Great', 'app', 'easier', 'access', 'of', 'info', '&amp;', 'ready', 'for', "Saturday's", 'run', 'http://t.co/ZyOFhZeRIO,positive']
# record
# "Today @YouTubeGaming launches, with apps for iOS and Android devices in the US and UK, here is what you need to know http://t.co/Kf8DgnHX9b",positive
#
# Tokens
# ['"Today', '@YouTubeGaming', 'launches,', 'with', 'apps', 'for', 'iOS', 'and', 'Android', 'devices', 'in', 'the', 'US', 'and', 'UK,', 'here', 'is', 'what', 'you', 'need', 'to', 'know', 'http://t.co/Kf8DgnHX9b",positive']
# record
# Got a project you want to work on? Need help with Swift? Need an excuse to hang with iOS devs on a Sat? Hang with us! http://t.co/pUWsKbDfWe,positive
#
# Tokens
# ['Got', 'a', 'project', 'you', 'want', 'to', 'work', 'on?', 'Need', 'help', 'with', 'Swift?', 'Need', 'an', 'excuse', 'to', 'hang', 'with', 'iOS', 'devs', 'on', 'a', 'Sat?', 'Hang', 'with', 'us!', 'http://t.co/pUWsKbDfWe,positive']
# record
# "Met with iOS Developer today. We may have a ""go"". 8-)",positive
#
# Tokens
# ['"Met', 'with', 'iOS', 'Developer', 'today.', 'We', 'may', 'have', 'a', '""go"".', '8-)",positive']
# record
# #CrossSkyHigh is going IOS #saturday. For now try this http://t.co/Jrc6ktK9rT #indiedev @GamerRTer @ShoutGamers http://t.co/bkWUjKEmju,positive
#
# Tokens
# ['#CrossSkyHigh', 'is', 'going', 'IOS', '#saturday.', 'For', 'now', 'try', 'this', 'http://t.co/Jrc6ktK9rT', '#indiedev', '@GamerRTer', '@ShoutGamers', 'http://t.co/bkWUjKEmju,positive']
# record
# What's the best way to get audio recordings from a 3rd party app off of an iOS device? Jailbreaking isn't an option.,positive
#
# Tokens
# ["What's", 'the', 'best', 'way', 'to', 'get', 'audio', 'recordings', 'from', 'a', '3rd', 'party', 'app', 'off', 'of', 'an', 'iOS', 'device?', 'Jailbreaking', "isn't", 'an', 'option.,positive']
# record
# Five Great Free Apps and Games for iOS - August 27th Edition:  It's that time of the week again... http://t.co/QGkrIrKI28 #News #LCHBuzz,positive
#
# Tokens
# ['Five', 'Great', 'Free', 'Apps', 'and', 'Games', 'for', 'iOS', '-', 'August', '27th', 'Edition:', "It's", 'that', 'time', 'of', 'the', 'week', 'again...', 'http://t.co/QGkrIrKI28', '#News', '#LCHBuzz,positive']
# record
# "@clayrussell @Nostradamion looks interesting but I've ALWAYS ended up back on iOS keyboard, always glitches with iOS 8/9 3rd party ones",neutral
#
# Tokens
# ['"@clayrussell', '@Nostradamion', 'looks', 'interesting', 'but', "I've", 'ALWAYS', 'ended', 'up', 'back', 'on', 'iOS', 'keyboard,', 'always', 'glitches', 'with', 'iOS', '8/9', '3rd', 'party', 'ones",neutral']
# record
# "See news through the eyes of real people &amp; be your own reporter with Fresco 2.0 for iOS, coming September 8th! http://t.co/IfLPLqqsmy",positive
#
# Tokens
# ['"See', 'news', 'through', 'the', 'eyes', 'of', 'real', 'people', '&amp;', 'be', 'your', 'own', 'reporter', 'with', 'Fresco', '2.0', 'for', 'iOS,', 'coming', 'September', '8th!', 'http://t.co/IfLPLqqsmy",positive']
# record
# Siri knows all about #Apple's iOS event on the 9th. #GiveUsAHint http://t.co/sHmTw46ELR,positive
#
# Tokens
# ['Siri', 'knows', 'all', 'about', "#Apple's", 'iOS', 'event', 'on', 'the', '9th.', '#GiveUsAHint', 'http://t.co/sHmTw46ELR,positive']
# record
# "Who's ready for 0.12.1 Build 12 Tomorrow, Might be the last build till it come to iOS !",positive
#
# Tokens
# ['"Who\'s', 'ready', 'for', '0.12.1', 'Build', '12', 'Tomorrow,', 'Might', 'be', 'the', 'last', 'build', 'till', 'it', 'come', 'to', 'iOS', '!",positive']
# record
# "@facebook As I've been on FB for many years, I have a few hundred photo albums, but only the 1st 200 appear in the IOS app. Is that right?",positive
#
# Tokens
# ['"@facebook', 'As', "I've", 'been', 'on', 'FB', 'for', 'many', 'years,', 'I', 'have', 'a', 'few', 'hundred', 'photo', 'albums,', 'but', 'only', 'the', '1st', '200', 'appear', 'in', 'the', 'IOS', 'app.', 'Is', 'that', 'right?",positive']
# record
# @Yurt try beat mp3 it may be on android i have it on ios and its fairly decent,positive
#
# Tokens
# ['@Yurt', 'try', 'beat', 'mp3', 'it', 'may', 'be', 'on', 'android', 'i', 'have', 'it', 'on', 'ios', 'and', 'its', 'fairly', 'decent,positive']
# record
# @androidcentral Even though there are other differences in the IOS features this still may make people lean a little more towards Apple.,positive
#
# Tokens
# ['@androidcentral', 'Even', 'though', 'there', 'are', 'other', 'differences', 'in', 'the', 'IOS', 'features', 'this', 'still', 'may', 'make', 'people', 'lean', 'a', 'little', 'more', 'towards', 'Apple.,positive']
# record
# Huawei Watch Pre-Order Suggests Android Wear Coming To iOS: IPhone owners who want to use Android Wear may soo... http://t.co/JQhdN5tCUV,neutral
#
# Tokens
# ['Huawei', 'Watch', 'Pre-Order', 'Suggests', 'Android', 'Wear', 'Coming', 'To', 'iOS:', 'IPhone', 'owners', 'who', 'want', 'to', 'use', 'Android', 'Wear', 'may', 'soo...', 'http://t.co/JQhdN5tCUV,neutral']
# record
# SpeedeNews: Rumor: Android Wear will soon work with iOS - Android Wear may be very close to working with iOS. That... http://t.co/pq0g0Z3eOy,neutral
#
# Tokens
# ['SpeedeNews:', 'Rumor:', 'Android', 'Wear', 'will', 'soon', 'work', 'with', 'iOS', '-', 'Android', 'Wear', 'may', 'be', 'very', 'close', 'to', 'working', 'with', 'iOS.', 'That...', 'http://t.co/pq0g0Z3eOy,neutral']
# record
# "Over here in NW near 11th &amp; Rhode Island, if you need a Lyft let me know !  Download the LYFT app for IOS or Android !",neutral
#
# Tokens
# ['"Over', 'here', 'in', 'NW', 'near', '11th', '&amp;', 'Rhode', 'Island,', 'if', 'you', 'need', 'a', 'Lyft', 'let', 'me', 'know', '!', 'Download', 'the', 'LYFT', 'app', 'for', 'IOS', 'or', 'Android', '!",neutral']
# record
# @NarisDRIFT @T_Dogg_94ebooks I wish that CustomFolderIcons worked on iOS 5.1.1 and it was received on December 11th.,neutral
#
# Tokens
# ['@NarisDRIFT', '@T_Dogg_94ebooks', 'I', 'wish', 'that', 'CustomFolderIcons', 'worked', 'on', 'iOS', '5.1.1', 'and', 'it', 'was', 'received', 'on', 'December', '11th.,neutral']
# record
# So today i checked my old iPod 4th gen which is on iOS 6.1.6 and it can't be upgraded further and i randomly open twitter,neutral
#
# Tokens
# ['So', 'today', 'i', 'checked', 'my', 'old', 'iPod', '4th', 'gen', 'which', 'is', 'on', 'iOS', '6.1.6', 'and', 'it', "can't", 'be', 'upgraded', 'further', 'and', 'i', 'randomly', 'open', 'twitter,neutral']
# record
# "@_tomcc @bartwerf please stop walking and work !! You have more than one month of late --"" The update was annonced the 29 of july, IOS wait!",negative
#
# Tokens
# ['"@_tomcc', '@bartwerf', 'please', 'stop', 'walking', 'and', 'work', '!!', 'You', 'have', 'more', 'than', 'one', 'month', 'of', 'late', '--""', 'The', 'update', 'was', 'annonced', 'the', '29', 'of', 'july,', 'IOS', 'wait!",negative']
# record
# "@notch  Hi i have heard that they said MCPE update 0,12,0/0,12,1 will come today 29 august to ios but i cant see that there is the update:)",positive
#
# Tokens
# ['"@notch', 'Hi', 'i', 'have', 'heard', 'that', 'they', 'said', 'MCPE', 'update', '0,12,0/0,12,1', 'will', 'come', 'today', '29', 'august', 'to', 'ios', 'but', 'i', 'cant', 'see', 'that', 'there', 'is', 'the', 'update:)",positive']
# record
# @Terraria_Logic do you have any news of an update in October for ios and android users,neutral
#
# Tokens
# ['@Terraria_Logic', 'do', 'you', 'have', 'any', 'news', 'of', 'an', 'update', 'in', 'October', 'for', 'ios', 'and', 'android', 'users,neutral']
# record
# "@alexdong a follow-on guess might be that if you are female, with an iOS device, visiting the site, you may have more disposable income?",neutral
#
# Tokens
# ['"@alexdong', 'a', 'follow-on', 'guess', 'might', 'be', 'that', 'if', 'you', 'are', 'female,', 'with', 'an', 'iOS', 'device,', 'visiting', 'the', 'site,', 'you', 'may', 'have', 'more', 'disposable', 'income?",neutral']
# record
# @tim_cook loving my new iPhone 6 from T-Mobile I'm in love with iOS! Can't wait for the Sept 9th event,positive
#
# Tokens
# ['@tim_cook', 'loving', 'my', 'new', 'iPhone', '6', 'from', 'T-Mobile', "I'm", 'in', 'love', 'with', 'iOS!', "Can't", 'wait', 'for', 'the', 'Sept', '9th', 'event,positive']
# record
# @M3RKMORK @MKBHD all Android wear is comparable with iOS now I believe. I may be wrong though,neutral
#
# Tokens
# ['@M3RKMORK', '@MKBHD', 'all', 'Android', 'wear', 'is', 'comparable', 'with', 'iOS', 'now', 'I', 'believe.', 'I', 'may', 'be', 'wrong', 'though,neutral']
# record
# Google Expands Android Wear Smartwatch Platform to iOS -  Google on Monday rolled out Android Wear smartwatch harmony with ...,neutral
#
# Tokens
# ['Google', 'Expands', 'Android', 'Wear', 'Smartwatch', 'Platform', 'to', 'iOS', '-', 'Google', 'on', 'Monday', 'rolled', 'out', 'Android', 'Wear', 'smartwatch', 'harmony', 'with', '...,neutral']
# record
# "@DeltaAssist yes, I asked an attendant to print out a paper pass. But this was not the 1st time delta IOS app lost my login info. Annoying.",negative
#
# Tokens
# ['"@DeltaAssist', 'yes,', 'I', 'asked', 'an', 'attendant', 'to', 'print', 'out', 'a', 'paper', 'pass.', 'But', 'this', 'was', 'not', 'the', '1st', 'time', 'delta', 'IOS', 'app', 'lost', 'my', 'login', 'info.', 'Annoying.",negative']
# record
# The two companies announced a partnership Monday aimed at making iOS devices and apps more compatible with... http://t.co/VeEFWrIUA9 #FF,positive
#
# Tokens
# ['The', 'two', 'companies', 'announced', 'a', 'partnership', 'Monday', 'aimed', 'at', 'making', 'iOS', 'devices', 'and', 'apps', 'more', 'compatible', 'with...', 'http://t.co/VeEFWrIUA9', '#FF,positive']
# record
# @rwang0 zeroes in on the latest in a short video. Making iPhone &amp; iOS great for enterprises. 1st @IBM &amp; now @Cisco. https://t.co/pheh3U4uxE,positive
#
# Tokens
# ['@rwang0', 'zeroes', 'in', 'on', 'the', 'latest', 'in', 'a', 'short', 'video.', 'Making', 'iPhone', '&amp;', 'iOS', 'great', 'for', 'enterprises.', '1st', '@IBM', '&amp;', 'now', '@Cisco.', 'https://t.co/pheh3U4uxE,positive']
# record
# To all Nintendo fans out there; I may sound crazy when I say this but Kirby and the rainbow curse and/or Kirby canvas curse should be on iOS,neutral
#
# Tokens
# ['To', 'all', 'Nintendo', 'fans', 'out', 'there;', 'I', 'may', 'sound', 'crazy', 'when', 'I', 'say', 'this', 'but', 'Kirby', 'and', 'the', 'rainbow', 'curse', 'and/or', 'Kirby', 'canvas', 'curse', 'should', 'be', 'on', 'iOS,neutral']
# record
# "Apple hasn't ever focused on gaming, but has enjoyed incredible success with iOS gaming. Apple TV may focus on games: http://t.co/Qn3wgy1KU7",neutral
#
# Tokens
# ['"Apple', "hasn't", 'ever', 'focused', 'on', 'gaming,', 'but', 'has', 'enjoyed', 'incredible', 'success', 'with', 'iOS', 'gaming.', 'Apple', 'TV', 'may', 'focus', 'on', 'games:', 'http://t.co/Qn3wgy1KU7",neutral']
# record
# @TimRaphael215 may want to pick your brains - looking to get into iOS dev myself.,neutral
#
# Tokens
# ['@TimRaphael215', 'may', 'want', 'to', 'pick', 'your', 'brains', '-', 'looking', 'to', 'get', 'into', 'iOS', 'dev', 'myself.,neutral']
# record
# The Orks are here to tell you that we're gunning for a Sept 30th release of Herald of Oblivion on iOS and Android! http://t.co/ZwGO1iDqo0,positive
#
# Tokens
# ['The', 'Orks', 'are', 'here', 'to', 'tell', 'you', 'that', "we're", 'gunning', 'for', 'a', 'Sept', '30th', 'release', 'of', 'Herald', 'of', 'Oblivion', 'on', 'iOS', 'and', 'Android!', 'http://t.co/ZwGO1iDqo0,positive']
# record
# "@deba1602 3rd party app on iOS, Does it add a keyboard or you have to type -&gt; copy -&gt; paste ? @debabrata2008",neutral
#
# Tokens
# ['"@deba1602', '3rd', 'party', 'app', 'on', 'iOS,', 'Does', 'it', 'add', 'a', 'keyboard', 'or', 'you', 'have', 'to', 'type', '-&gt;', 'copy', '-&gt;', 'paste', '?', '@debabrata2008",neutral']
# record
# M/T Webroot: Have a jailbroken iOS device? You may want to reconsider. http://t.co/2QFA6jFLNf,neutral
#
# Tokens
# ['M/T', 'Webroot:', 'Have', 'a', 'jailbroken', 'iOS', 'device?', 'You', 'may', 'want', 'to', 'reconsider.', 'http://t.co/2QFA6jFLNf,neutral']
# record
# "@icj_ i have the Ipod Touch 5th and i have the IOS 8.4.1,ofc i cant downgrade because 8.4 is not being signded,so now what i supposed to do?",neutral
#
# Tokens
# ['"@icj_', 'i', 'have', 'the', 'Ipod', 'Touch', '5th', 'and', 'i', 'have', 'the', 'IOS', '8.4.1,ofc', 'i', 'cant', 'downgrade', 'because', '8.4', 'is', 'not', 'being', 'signded,so', 'now', 'what', 'i', 'supposed', 'to', 'do?",neutral']
# record
# "@arekdreyer Making my way through your Managing iOS and Macs 2nd Ed. book. Great read, really well done! Thanks for doing this; keep it up.",positive
#
# Tokens
# ['"@arekdreyer', 'Making', 'my', 'way', 'through', 'your', 'Managing', 'iOS', 'and', 'Macs', '2nd', 'Ed.', 'book.', 'Great', 'read,', 'really', 'well', 'done!', 'Thanks', 'for', 'doing', 'this;', 'keep', 'it', 'up.",positive']
# record
# "Google's Android Wear for iOS confirmed incompatible with Apple's HealthKit: In announcing Android Wear for iOS on Monday, Google not...",neutral
#
# Tokens
# ['"Google\'s', 'Android', 'Wear', 'for', 'iOS', 'confirmed', 'incompatible', 'with', "Apple's", 'HealthKit:', 'In', 'announcing', 'Android', 'Wear', 'for', 'iOS', 'on', 'Monday,', 'Google', 'not...",neutral']
# record
# @LeeQVC Hi Lee my iPhone is currently operating on IOS 6do I have to put IOS7 1st or can upload IOS8 if so how do I go about it ?,neutral
#
# Tokens
# ['@LeeQVC', 'Hi', 'Lee', 'my', 'iPhone', 'is', 'currently', 'operating', 'on', 'IOS', '6do', 'I', 'have', 'to', 'put', 'IOS7', '1st', 'or', 'can', 'upload', 'IOS8', 'if', 'so', 'how', 'do', 'I', 'go', 'about', 'it', '?,neutral']
# record
# wed night 7pm pacific join the The BLAST! live right here on FB as we have the founder's of the IOS app Kander on... http://t.co/XgeUKCqd6f,positive
#
# Tokens
# ['wed', 'night', '7pm', 'pacific', 'join', 'the', 'The', 'BLAST!', 'live', 'right', 'here', 'on', 'FB', 'as', 'we', 'have', 'the', "founder's", 'of', 'the', 'IOS', 'app', 'Kander', 'on...', 'http://t.co/XgeUKCqd6f,positive']
# record
# codigames:Do you like ARPGs?Dungeon Legends arrive to iOS on September 3rd http://t.co/17VP9iXAxj #gamedev #iphone http://t.co/vGQF11yE2H,positive
#
# Tokens
# ['codigames:Do', 'you', 'like', 'ARPGs?Dungeon', 'Legends', 'arrive', 'to', 'iOS', 'on', 'September', '3rd', 'http://t.co/17VP9iXAxj', '#gamedev', '#iphone', 'http://t.co/vGQF11yE2H,positive']
# record
# Jailbreaking iOS Devices May Not Be The Best Idea: Security vulnerabilities in the iOS can rarely be... http://t.co/yAATcrXOrU #security,neutral
#
# Tokens
# ['Jailbreaking', 'iOS', 'Devices', 'May', 'Not', 'Be', 'The', 'Best', 'Idea:', 'Security', 'vulnerabilities', 'in', 'the', 'iOS', 'can', 'rarely', 'be...', 'http://t.co/yAATcrXOrU', '#security,neutral']
# record
# "Come and have the FIRST EVER GO on Lumino City on iOS @SomersetHouse @nowplaythese + real models, Friday til Sunday! http://t.co/GXdkU8COnj",positive
#
# Tokens
# ['"Come', 'and', 'have', 'the', 'FIRST', 'EVER', 'GO', 'on', 'Lumino', 'City', 'on', 'iOS', '@SomersetHouse', '@nowplaythese', '+', 'real', 'models,', 'Friday', 'til', 'Sunday!', 'http://t.co/GXdkU8COnj",positive']
# record
# Rumor has it that a certain app is available on iOS and it's FREE.  Android coming Friday. http://t.co/JXNaqgUWaz,neutral
#
# Tokens
# ['Rumor', 'has', 'it', 'that', 'a', 'certain', 'app', 'is', 'available', 'on', 'iOS', 'and', "it's", 'FREE.', 'Android', 'coming', 'Friday.', 'http://t.co/JXNaqgUWaz,neutral']
# record
# @steveballin So far we've announced iOS and Android versions and we focus on them. This may change in the future though.,neutral
#
# Tokens
# ['@steveballin', 'So', 'far', "we've", 'announced', 'iOS', 'and', 'Android', 'versions', 'and', 'we', 'focus', 'on', 'them.', 'This', 'may', 'change', 'in', 'the', 'future', 'though.,neutral']
# record
# "@MyersNFL May favorite one EVER on iOS is Harbaugh, it autocorrects to Garbage",neutral
#
# Tokens
# ['"@MyersNFL', 'May', 'favorite', 'one', 'EVER', 'on', 'iOS', 'is', 'Harbaugh,', 'it', 'autocorrects', 'to', 'Garbage",neutral']
# record
# @MKBHD do u know if the moto360 2nd gen will work with iOS devices??,neutral
#
# Tokens
# ['@MKBHD', 'do', 'u', 'know', 'if', 'the', 'moto360', '2nd', 'gen', 'will', 'work', 'with', 'iOS', 'devices??,neutral']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# My best guess is we should see MCPE0.12.0 submitted to IOS and Google by the end of week or into Monday if the devs have cleaned up the bugs,positive
#
# Tokens
# ['My', 'best', 'guess', 'is', 'we', 'should', 'see', 'MCPE0.12.0', 'submitted', 'to', 'IOS', 'and', 'Google', 'by', 'the', 'end', 'of', 'week', 'or', 'into', 'Monday', 'if', 'the', 'devs', 'have', 'cleaned', 'up', 'the', 'bugs,positive']
# record
# The next Pixel Dungeon update for Steam and iOS with a lot of new features and improvements will be released on September 4th.,positive
#
# Tokens
# ['The', 'next', 'Pixel', 'Dungeon', 'update', 'for', 'Steam', 'and', 'iOS', 'with', 'a', 'lot', 'of', 'new', 'features', 'and', 'improvements', 'will', 'be', 'released', 'on', 'September', '4th.,positive']
# record
# Thursday Night on KXLU! Get the @KXLU889 app for IOS or Android at http://t.co/hDxy5DKgp7 and LISTEN! http://t.co/bjODczV0MF,neutral
#
# Tokens
# ['Thursday', 'Night', 'on', 'KXLU!', 'Get', 'the', '@KXLU889', 'app', 'for', 'IOS', 'or', 'Android', 'at', 'http://t.co/hDxy5DKgp7', 'and', 'LISTEN!', 'http://t.co/bjODczV0MF,neutral']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# Been using Vodafone's smart ultra 6 since Tuesday. Can't get the hang of it and finding a few faults with android. Back to IOS I think...,neutral
#
# Tokens
# ['Been', 'using', "Vodafone's", 'smart', 'ultra', '6', 'since', 'Tuesday.', "Can't", 'get', 'the', 'hang', 'of', 'it', 'and', 'finding', 'a', 'few', 'faults', 'with', 'android.', 'Back', 'to', 'IOS', 'I', 'think...,neutral']
# record
# "Meet your new (old) favorite endless runner for iOS, Race the Sun - Macworld http://t.co/or8gZl9CsG",neutral
#
# Tokens
# ['"Meet', 'your', 'new', '(old)', 'favorite', 'endless', 'runner', 'for', 'iOS,', 'Race', 'the', 'Sun', '-', 'Macworld', 'http://t.co/or8gZl9CsG",neutral']
# record
# "Are you ready for our new 2048 app launch tomorrow? Build binaries for IOS, Android, Windows Phones and Tablets.... http://t.co/pmCGUUu6cL",positive
#
# Tokens
# ['"Are', 'you', 'ready', 'for', 'our', 'new', '2048', 'app', 'launch', 'tomorrow?', 'Build', 'binaries', 'for', 'IOS,', 'Android,', 'Windows', 'Phones', 'and', 'Tablets....', 'http://t.co/pmCGUUu6cL",positive']
# record
# @flyshorts BTW I &amp; others have run into a fair number of cataloguing issues with the Apple Music update in iOS 8.4. This may be a symptom.,neutral
#
# Tokens
# ['@flyshorts', 'BTW', 'I', '&amp;', 'others', 'have', 'run', 'into', 'a', 'fair', 'number', 'of', 'cataloguing', 'issues', 'with', 'the', 'Apple', 'Music', 'update', 'in', 'iOS', '8.4.', 'This', 'may', 'be', 'a', 'symptom.,neutral']
# record
# This hopefully means that MCPE will come out for IOS around the 8th of September along with all other versions!,positive
#
# Tokens
# ['This', 'hopefully', 'means', 'that', 'MCPE', 'will', 'come', 'out', 'for', 'IOS', 'around', 'the', '8th', 'of', 'September', 'along', 'with', 'all', 'other', 'versions!,positive']
# record
# What you should look for from Apple's September 9 event: A new version of iOS will likely arrive with those sh... http://t.co/TcdFrMhODo,positive
#
# Tokens
# ['What', 'you', 'should', 'look', 'for', 'from', "Apple's", 'September', '9', 'event:', 'A', 'new', 'version', 'of', 'iOS', 'will', 'likely', 'arrive', 'with', 'those', 'sh...', 'http://t.co/TcdFrMhODo,positive']
# record
# Want to speed up your sharing? Automate a few things from your iOS device? Workflow may be the solution. http://t.co/cVkMkRCeDq,neutral
#
# Tokens
# ['Want', 'to', 'speed', 'up', 'your', 'sharing?', 'Automate', 'a', 'few', 'things', 'from', 'your', 'iOS', 'device?', 'Workflow', 'may', 'be', 'the', 'solution.', 'http://t.co/cVkMkRCeDq,neutral']
# record
# @RobloxLeaksFTW thank you now I may actually have a chance on ios now,positive
#
# Tokens
# ['@RobloxLeaksFTW', 'thank', 'you', 'now', 'I', 'may', 'actually', 'have', 'a', 'chance', 'on', 'ios', 'now,positive']
# record
# articlesection classpagepAndroid Wear may be very close to working with iOS,positive
#
# Tokens
# ['articlesection', 'classpagepAndroid', 'Wear', 'may', 'be', 'very', 'close', 'to', 'working', 'with', 'iOS,positive']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# @_tomcc Hey Tommaso when is the release date for 0.12 on iOS? If the answer is around the 8th thats where my school starts!,positive
#
# Tokens
# ['@_tomcc', 'Hey', 'Tommaso', 'when', 'is', 'the', 'release', 'date', 'for', '0.12', 'on', 'iOS?', 'If', 'the', 'answer', 'is', 'around', 'the', '8th', 'thats', 'where', 'my', 'school', 'starts!,positive']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# 1 DAY.#CrowdViz releases on Labor Day September 7th! An IOS app that unites blind people with sighted assistants. http://t.co/fNXqXa685P,positive
#
# Tokens
# ['1', 'DAY.#CrowdViz', 'releases', 'on', 'Labor', 'Day', 'September', '7th!', 'An', 'IOS', 'app', 'that', 'unites', 'blind', 'people', 'with', 'sighted', 'assistants.', 'http://t.co/fNXqXa685P,positive']
# record
# WHO CANT WAIT FOR MINECRAFT 0.12 ON IOS BUT NOW U DONT HAVE TO WAIT CAUSE IT WILL BE SUBMITTED AT 8th september 1 day left,positive
#
# Tokens
# ['WHO', 'CANT', 'WAIT', 'FOR', 'MINECRAFT', '0.12', 'ON', 'IOS', 'BUT', 'NOW', 'U', 'DONT', 'HAVE', 'TO', 'WAIT', 'CAUSE', 'IT', 'WILL', 'BE', 'SUBMITTED', 'AT', '8th', 'september', '1', 'day', 'left,positive']
# record
# It's quite funny to see iOS developers taking advantage of the new Ugmonk 6th Anniversary set!,neutral
#
# Tokens
# ["It's", 'quite', 'funny', 'to', 'see', 'iOS', 'developers', 'taking', 'advantage', 'of', 'the', 'new', 'Ugmonk', '6th', 'Anniversary', 'set!,neutral']
# record
# Not Available,negative
#
# Tokens
# ['Not', 'Available,negative']
# record
# "@KymLang links are working fine on my IOS device. Some times on the first click I get a ""open in safari ?"" Cancel it &amp; do a 2nd click. Works",positive
#
# Tokens
# ['"@KymLang', 'links', 'are', 'working', 'fine', 'on', 'my', 'IOS', 'device.', 'Some', 'times', 'on', 'the', 'first', 'click', 'I', 'get', 'a', '""open', 'in', 'safari', '?""', 'Cancel', 'it', '&amp;', 'do', 'a', '2nd', 'click.', 'Works",positive']
# record
# "@darngeek all device build 14 tomorrow or official (WP,android,IOS) ? Hehe :P yay happy day for you ...",positive
#
# Tokens
# ['"@darngeek', 'all', 'device', 'build', '14', 'tomorrow', 'or', 'official', '(WP,android,IOS)', '?', 'Hehe', ':P', 'yay', 'happy', 'day', 'for', 'you', '...",positive']
# record
# @_tomcc so the 12.0 for IOS will be out tomorrow correct??,neutral
#
# Tokens
# ['@_tomcc', 'so', 'the', '12.0', 'for', 'IOS', 'will', 'be', 'out', 'tomorrow', 'correct??,neutral']
# record
# Tech: Android&gt;Star Wars: Uprising launches September 10 on iOS and Android - GB: Star Wars canon is about t..http://t.co/oiTvPxGfby #mobile,positive
#
# Tokens
# ['Tech:', 'Android&gt;Star', 'Wars:', 'Uprising', 'launches', 'September', '10', 'on', 'iOS', 'and', 'Android', '-', 'GB:', 'Star', 'Wars', 'canon', 'is', 'about', 't..http://t.co/oiTvPxGfby', '#mobile,positive']
# record
# @_tomcc hi I was wondering do u mean you'll try to release MCPE 0.12.1 to iOS tomorrow??? Ps your awesome,positive
#
# Tokens
# ['@_tomcc', 'hi', 'I', 'was', 'wondering', 'do', 'u', 'mean', "you'll", 'try', 'to', 'release', 'MCPE', '0.12.1', 'to', 'iOS', 'tomorrow???', 'Ps', 'your', 'awesome,positive']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# Check out my ride in #CSRRacing for iOS! Try it for FREE! http://t.co/BvKgJ02yP8 now car http://t.co/PLHShHhLA0,positive
#
# Tokens
# ['Check', 'out', 'my', 'ride', 'in', '#CSRRacing', 'for', 'iOS!', 'Try', 'it', 'for', 'FREE!', 'http://t.co/BvKgJ02yP8', 'now', 'car', 'http://t.co/PLHShHhLA0,positive']
# record
# Apple releases what the next iPhones and IOS will be like tomorrow,neutral
#
# Tokens
# ['Apple', 'releases', 'what', 'the', 'next', 'iPhones', 'and', 'IOS', 'will', 'be', 'like', 'tomorrow,neutral']
# record
# You can download 0.12.0 for iOS and the show or server won't work until tomorrow be happy and SMILE MORE =),positive
#
# Tokens
# ['You', 'can', 'download', '0.12.0', 'for', 'iOS', 'and', 'the', 'show', 'or', 'server', "won't", 'work', 'until', 'tomorrow', 'be', 'happy', 'and', 'SMILE', 'MORE', '=),positive']
# record
# "Those of you with iOS devices, ask Siri to ""give you a hint"" about tomorrow's Apple keynote. http://t.co/pfQkdUDchQ",positive
#
# Tokens
# ['"Those', 'of', 'you', 'with', 'iOS', 'devices,', 'ask', 'Siri', 'to', '""give', 'you', 'a', 'hint""', 'about', "tomorrow's", 'Apple', 'keynote.', 'http://t.co/pfQkdUDchQ",positive']
# record
# I don't operate any iOS devices anymore but I'll still tune into the big show tomorrow. Still fun to watch the event and see what's what.,positive
#
# Tokens
# ['I', "don't", 'operate', 'any', 'iOS', 'devices', 'anymore', 'but', "I'll", 'still', 'tune', 'into', 'the', 'big', 'show', 'tomorrow.', 'Still', 'fun', 'to', 'watch', 'the', 'event', 'and', 'see', "what's", 'what.,positive']
# record
# @pedstrom Not sure what you mean. Continuity doesn't require a separate 3rd device (Watch) for two (other) iOS devices to pair and share.,neutral
#
# Tokens
# ['@pedstrom', 'Not', 'sure', 'what', 'you', 'mean.', 'Continuity', "doesn't", 'require', 'a', 'separate', '3rd', 'device', '(Watch)', 'for', 'two', '(other)', 'iOS', 'devices', 'to', 'pair', 'and', 'share.,neutral']
# record
# ok inbox on iOS has a pretty animation for the sun but thew android version doesnt :(,negative
#
# Tokens
# ['ok', 'inbox', 'on', 'iOS', 'has', 'a', 'pretty', 'animation', 'for', 'the', 'sun', 'but', 'thew', 'android', 'version', 'doesnt', ':(,negative']
# record
# @AGPlaya the only time i would say i really enjoyed IOS was fifa 14 before i got my console in may soon as i got that i stopped playing it,neutral
#
# Tokens
# ['@AGPlaya', 'the', 'only', 'time', 'i', 'would', 'say', 'i', 'really', 'enjoyed', 'IOS', 'was', 'fifa', '14', 'before', 'i', 'got', 'my', 'console', 'in', 'may', 'soon', 'as', 'i', 'got', 'that', 'i', 'stopped', 'playing', 'it,neutral']
# record
# "Wanna watch the iPhone announcement... LIVE? With any iOS device (Safari Browser)... watch here, starting 10 AM PST: http://t.co/ty3GDrguxn",positive
#
# Tokens
# ['"Wanna', 'watch', 'the', 'iPhone', 'announcement...', 'LIVE?', 'With', 'any', 'iOS', 'device', '(Safari', 'Browser)...', 'watch', 'here,', 'starting', '10', 'AM', 'PST:', 'http://t.co/ty3GDrguxn",positive']
# record
# "ATTN: Beginning Oct 1st, Munzee 3.0 will be the only app available for iOS and Android. Also, 3.0.1 is in review and includes bug fixes.",positive
#
# Tokens
# ['"ATTN:', 'Beginning', 'Oct', '1st,', 'Munzee', '3.0', 'will', 'be', 'the', 'only', 'app', 'available', 'for', 'iOS', 'and', 'Android.', 'Also,', '3.0.1', 'is', 'in', 'review', 'and', 'includes', 'bug', 'fixes.",positive']
# record
# Did you know that we are launching @eccgames's Tower Dwellers Gold on Android tomorrow in tandem with iOS?  https://t.co/PIBCmp1bzd,positive
#
# Tokens
# ['Did', 'you', 'know', 'that', 'we', 'are', 'launching', "@eccgames's", 'Tower', 'Dwellers', 'Gold', 'on', 'Android', 'tomorrow', 'in', 'tandem', 'with', 'iOS?', 'https://t.co/PIBCmp1bzd,positive']
# record
# http://t.co/DeGqRngcwk: iOS Developer  TH-Bangkok: Market Rate:  http://t.co/DeGqRngcwk: My client is the larges... http://t.co/kYSJ5sThUE,neutral
#
# Tokens
# ['http://t.co/DeGqRngcwk:', 'iOS', 'Developer', 'TH-Bangkok:', 'Market', 'Rate:', 'http://t.co/DeGqRngcwk:', 'My', 'client', 'is', 'the', 'larges...', 'http://t.co/kYSJ5sThUE,neutral']
# record
# "Like legit though, if it was running OS X, it would be a sick product. But since it's running IOS you may as well get a retina 13""",positive
#
# Tokens
# ['"Like', 'legit', 'though,', 'if', 'it', 'was', 'running', 'OS', 'X,', 'it', 'would', 'be', 'a', 'sick', 'product.', 'But', 'since', "it's", 'running', 'IOS', 'you', 'may', 'as', 'well', 'get', 'a', 'retina', '13""",positive']
# record
# Join the MOVable Challenge! Get your MOVband at Spirit Fest tomorrow or Thursday and move one step closer to an iPad! http://t.co/QEv1anI83s,positive
#
# Tokens
# ['Join', 'the', 'MOVable', 'Challenge!', 'Get', 'your', 'MOVband', 'at', 'Spirit', 'Fest', 'tomorrow', 'or', 'Thursday', 'and', 'move', 'one', 'step', 'closer', 'to', 'an', 'iPad!', 'http://t.co/QEv1anI83s,positive']
# record
# "tomorrow is another big day in the tech world! I'm guessing a new upgraded  iPhone, iPad, and possibly new OS! http://t.co/ro5a6NIgAa",positive
#
# Tokens
# ['"tomorrow', 'is', 'another', 'big', 'day', 'in', 'the', 'tech', 'world!', "I'm", 'guessing', 'a', 'new', 'upgraded', 'iPhone,', 'iPad,', 'and', 'possibly', 'new', 'OS!', 'http://t.co/ro5a6NIgAa",positive']
# record
# Lost my iPad for the 2nd time today,negative
#
# Tokens
# ['Lost', 'my', 'iPad', 'for', 'the', '2nd', 'time', 'today,negative']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# Woods Club! @CHSWoodsClub Come to room 175 after school next tuesday to make iPad Stands! http://t.co/U0aqa81PWW,positive
#
# Tokens
# ['Woods', 'Club!', '@CHSWoodsClub', 'Come', 'to', 'room', '175', 'after', 'school', 'next', 'tuesday', 'to', 'make', 'iPad', 'Stands!', 'http://t.co/U0aqa81PWW,positive']
# record
# A survey question ahead of tomorrow's announcements: What's the right price for an 12.9-inch iPad w stylus and keyboard cover??,neutral
#
# Tokens
# ['A', 'survey', 'question', 'ahead', 'of', "tomorrow's", 'announcements:', "What's", 'the', 'right', 'price', 'for', 'an', '12.9-inch', 'iPad', 'w', 'stylus', 'and', 'keyboard', 'cover??,neutral']
# record
# "Really excited about Apple Announcing iPad Pro tomorrow. Ah, the rumor I've been wanting to be true for years. It... http://t.co/BNFovY0ZBZ",positive
#
# Tokens
# ['"Really', 'excited', 'about', 'Apple', 'Announcing', 'iPad', 'Pro', 'tomorrow.', 'Ah,', 'the', 'rumor', "I've", 'been', 'wanting', 'to', 'be', 'true', 'for', 'years.', 'It...', 'http://t.co/BNFovY0ZBZ",positive']
# record
# So excited to see what #Apple announces! My wish - a huge iPad that I can draw on with a stylus http://t.co/FeTK7rajmb @WIRED #tech,positive
#
# Tokens
# ['So', 'excited', 'to', 'see', 'what', '#Apple', 'announces!', 'My', 'wish', '-', 'a', 'huge', 'iPad', 'that', 'I', 'can', 'draw', 'on', 'with', 'a', 'stylus', 'http://t.co/FeTK7rajmb', '@WIRED', '#tech,positive']
# record
# Apple might want to give devs a little info on iPad Pro before dropping it and iOS 9.1 on the market in November. ht: @apollozac,neutral
#
# Tokens
# ['Apple', 'might', 'want', 'to', 'give', 'devs', 'a', 'little', 'info', 'on', 'iPad', 'Pro', 'before', 'dropping', 'it', 'and', 'iOS', '9.1', 'on', 'the', 'market', 'in', 'November.', 'ht:', '@apollozac,neutral']
# record
# Sat next to a woman on the plane today who flipped through photos of her cat on her iPad the whole time. #spiritanimal,positive
#
# Tokens
# ['Sat', 'next', 'to', 'a', 'woman', 'on', 'the', 'plane', 'today', 'who', 'flipped', 'through', 'photos', 'of', 'her', 'cat', 'on', 'her', 'iPad', 'the', 'whole', 'time.', '#spiritanimal,positive']
# record
# Tomorrow the day Apple reveals a new iPhone &amp; iPad #SoAnxious I want both items ASAP!,positive
#
# Tokens
# ['Tomorrow', 'the', 'day', 'Apple', 'reveals', 'a', 'new', 'iPhone', '&amp;', 'iPad', '#SoAnxious', 'I', 'want', 'both', 'items', 'ASAP!,positive']
# record
# "Prediction for tomorrow: iPhone 6c, 6s and 6s+; a 12"" iPad and a new Apple TV with touchscreen controller. #applegenius #stillnojobthough",positive
#
# Tokens
# ['"Prediction', 'for', 'tomorrow:', 'iPhone', '6c,', '6s', 'and', '6s+;', 'a', '12""', 'iPad', 'and', 'a', 'new', 'Apple', 'TV', 'with', 'touchscreen', 'controller.', '#applegenius', '#stillnojobthough",positive']
# record
# "Rumor is that Apple's big announcement tomorrow is a giant iPad. Please, God -- please let them call it the MaxiPad! #AppleEvent #Apple",positive
#
# Tokens
# ['"Rumor', 'is', 'that', "Apple's", 'big', 'announcement', 'tomorrow', 'is', 'a', 'giant', 'iPad.', 'Please,', 'God', '--', 'please', 'let', 'them', 'call', 'it', 'the', 'MaxiPad!', '#AppleEvent', '#Apple",positive']
# record
# "Tomorrow: Capturing Covent Garden with iPhone and iPad 9 September, 10:30am, Apple Store, Covent Garden. #Free http://t.co/HLqZo2ff8G",positive
#
# Tokens
# ['"Tomorrow:', 'Capturing', 'Covent', 'Garden', 'with', 'iPhone', 'and', 'iPad', '9', 'September,', '10:30am,', 'Apple', 'Store,', 'Covent', 'Garden.', '#Free', 'http://t.co/HLqZo2ff8G",positive']
# record
# "I'm at my follow limit. Rude. I will go on my iPad tomorrow and unfollow all the little bitches who ain't following back. K, bye.",negative
#
# Tokens
# ['"I\'m', 'at', 'my', 'follow', 'limit.', 'Rude.', 'I', 'will', 'go', 'on', 'my', 'iPad', 'tomorrow', 'and', 'unfollow', 'all', 'the', 'little', 'bitches', 'who', "ain't", 'following', 'back.', 'K,', 'bye.",negative']
# record
# Wouldn't be surprised if the new iPhone unveiled tomorrow is actually an iPad mini,positive
#
# Tokens
# ["Wouldn't", 'be', 'surprised', 'if', 'the', 'new', 'iPhone', 'unveiled', 'tomorrow', 'is', 'actually', 'an', 'iPad', 'mini,positive']
# record
# @coorz00 thanks tea sounds good but gotta update the iPad 1st,positive
#
# Tokens
# ['@coorz00', 'thanks', 'tea', 'sounds', 'good', 'but', 'gotta', 'update', 'the', 'iPad', '1st,positive']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# I hope they announce something different and exciting for the iPad tomorrow. It's just about time for me to get a new one #AppleEvent,positive
#
# Tokens
# ['I', 'hope', 'they', 'announce', 'something', 'different', 'and', 'exciting', 'for', 'the', 'iPad', 'tomorrow.', "It's", 'just', 'about', 'time', 'for', 'me', 'to', 'get', 'a', 'new', 'one', '#AppleEvent,positive']
# record
# "Reading @daringfireball's prelude to tomorrow's Apple event, can't help but think @gruber is the new WSJ, Bloomberg, or NYT re: iPad news.",positive
#
# Tokens
# ['"Reading', "@daringfireball's", 'prelude', 'to', "tomorrow's", 'Apple', 'event,', "can't", 'help', 'but', 'think', '@gruber', 'is', 'the', 'new', 'WSJ,', 'Bloomberg,', 'or', 'NYT', 're:', 'iPad', 'news.",positive']
# record
# Traded in the new computer to get an iPad. Uncle tells me new iPad will be announced tomorrow so prices should drop. http://t.co/3Xgg14mX62,positive
#
# Tokens
# ['Traded', 'in', 'the', 'new', 'computer', 'to', 'get', 'an', 'iPad.', 'Uncle', 'tells', 'me', 'new', 'iPad', 'will', 'be', 'announced', 'tomorrow', 'so', 'prices', 'should', 'drop.', 'http://t.co/3Xgg14mX62,positive']
# record
# "Apple's Keynote is happening tomorrow at 3am!With the expected announcement of the iPhone 6S, new Apple TV and iPad who is waking up for it?",positive
#
# Tokens
# ['"Apple\'s', 'Keynote', 'is', 'happening', 'tomorrow', 'at', '3am!With', 'the', 'expected', 'announcement', 'of', 'the', 'iPhone', '6S,', 'new', 'Apple', 'TV', 'and', 'iPad', 'who', 'is', 'waking', 'up', 'for', 'it?",positive']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# The only thing I'm looking forward to tomorrow is the new iPhone and iPad Pro,positive
#
# Tokens
# ['The', 'only', 'thing', "I'm", 'looking', 'forward', 'to', 'tomorrow', 'is', 'the', 'new', 'iPhone', 'and', 'iPad', 'Pro,positive']
# record
# what she gonna buy with $200? 1/4th of an ipad  https://t.co/SL79vF03CE,neutral
#
# Tokens
# ['what', 'she', 'gonna', 'buy', 'with', '$200?', '1/4th', 'of', 'an', 'ipad', 'https://t.co/SL79vF03CE,neutral']
# record
# I hope I get my iPad tomorrow so I can stream the Apple Keynote Address in school,positive
#
# Tokens
# ['I', 'hope', 'I', 'get', 'my', 'iPad', 'tomorrow', 'so', 'I', 'can', 'stream', 'the', 'Apple', 'Keynote', 'Address', 'in', 'school,positive']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# "Does it really have iPad pro &amp; stylus, tomorrow will have answer!!!",positive
#
# Tokens
# ['"Does', 'it', 'really', 'have', 'iPad', 'pro', '&amp;', 'stylus,', 'tomorrow', 'will', 'have', 'answer!!!",positive']
# record
# @Dennisd1971 if you are using an iPhone or iPad you may not be able to view it their youtube app.  Try on your computer.,neutral
#
# Tokens
# ['@Dennisd1971', 'if', 'you', 'are', 'using', 'an', 'iPhone', 'or', 'iPad', 'you', 'may', 'not', 'be', 'able', 'to', 'view', 'it', 'their', 'youtube', 'app.', 'Try', 'on', 'your', 'computer.,neutral']
# record
# "Tomorrow, #Apple better introduce an iPad large enough for me to stand on, with an app that'll transport me wherever I want to go. If not...",neutral
#
# Tokens
# ['"Tomorrow,', '#Apple', 'better', 'introduce', 'an', 'iPad', 'large', 'enough', 'for', 'me', 'to', 'stand', 'on,', 'with', 'an', 'app', "that'll", 'transport', 'me', 'wherever', 'I', 'want', 'to', 'go.', 'If', 'not...",neutral']
# record
# "But with a new iPad coming out, I may be able to snag an older iPad at a decent price.",positive
#
# Tokens
# ['"But', 'with', 'a', 'new', 'iPad', 'coming', 'out,', 'I', 'may', 'be', 'able', 'to', 'snag', 'an', 'older', 'iPad', 'at', 'a', 'decent', 'price.",positive']
# record
# First day of school tomorrow which means it's also the first day of the season for RBI baseball on my iPad,positive
#
# Tokens
# ['First', 'day', 'of', 'school', 'tomorrow', 'which', 'means', "it's", 'also', 'the', 'first', 'day', 'of', 'the', 'season', 'for', 'RBI', 'baseball', 'on', 'my', 'iPad,positive']
# record
# "are yall really mad that he's paying $200 to fix a broken iPad, don't yall have bigger problems to deal with  https://t.co/bDigQfbZOd",negative
#
# Tokens
# ['"are', 'yall', 'really', 'mad', 'that', "he's", 'paying', '$200', 'to', 'fix', 'a', 'broken', 'iPad,', "don't", 'yall', 'have', 'bigger', 'problems', 'to', 'deal', 'with', 'https://t.co/bDigQfbZOd",negative']
# record
# And Apple goes gesture controlled gaming with Apple TV. Will the phone and iPad upgrades impress?  https://t.co/nAwH8kht9B,positive
#
# Tokens
# ['And', 'Apple', 'goes', 'gesture', 'controlled', 'gaming', 'with', 'Apple', 'TV.', 'Will', 'the', 'phone', 'and', 'iPad', 'upgrades', 'impress?', 'https://t.co/nAwH8kht9B,positive']
# record
# "#Apple to unveil iPhone 6s, iPad today. For the first time they are releasing on Wednesday. All their earlier releases were on a Tuesday.",positive
#
# Tokens
# ['"#Apple', 'to', 'unveil', 'iPhone', '6s,', 'iPad', 'today.', 'For', 'the', 'first', 'time', 'they', 'are', 'releasing', 'on', 'Wednesday.', 'All', 'their', 'earlier', 'releases', 'were', 'on', 'a', 'Tuesday.",positive']
# record
# When you have 3 1/2 tests tomorrow and a lab to do but your iPad is dead so you can't do shit :):):):):):),negative
#
# Tokens
# ['When', 'you', 'have', '3', '1/2', 'tests', 'tomorrow', 'and', 'a', 'lab', 'to', 'do', 'but', 'your', 'iPad', 'is', 'dead', 'so', 'you', "can't", 'do', 'shit', ':):):):):):),negative']
# record
# Highly doubt that iPad will be covered during the #AppleEvent tomorrow. https://t.co/qndgNTztqa,negative
#
# Tokens
# ['Highly', 'doubt', 'that', 'iPad', 'will', 'be', 'covered', 'during', 'the', '#AppleEvent', 'tomorrow.', 'https://t.co/qndgNTztqa,negative']
# record
# "So tomorrow is the big Apple event. What do you think we'll see, iPad Pro? An iPad Stylus? Curious to see what they bring.",positive
#
# Tokens
# ['"So', 'tomorrow', 'is', 'the', 'big', 'Apple', 'event.', 'What', 'do', 'you', 'think', "we'll", 'see,', 'iPad', 'Pro?', 'An', 'iPad', 'Stylus?', 'Curious', 'to', 'see', 'what', 'they', 'bring.",positive']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# "Checks 2.0 will not be submitted tomorrow, but I'll end up taking the extra time for a watch app, NC widget, iPad optimization, etc.",neutral
#
# Tokens
# ['"Checks', '2.0', 'will', 'not', 'be', 'submitted', 'tomorrow,', 'but', "I'll", 'end', 'up', 'taking', 'the', 'extra', 'time', 'for', 'a', 'watch', 'app,', 'NC', 'widget,', 'iPad', 'optimization,', 'etc.",neutral']
# record
# @LOHANTHONY my moms taking my iPad away tomorrow but it's worth it because I'm tweeting the KWEENT #ANTHONYCHAT,positive
#
# Tokens
# ['@LOHANTHONY', 'my', 'moms', 'taking', 'my', 'iPad', 'away', 'tomorrow', 'but', "it's", 'worth', 'it', 'because', "I'm", 'tweeting', 'the', 'KWEENT', '#ANTHONYCHAT,positive']
# record
# "Which is more interesting unveil tomorrow? $AAPL 6s, Ipad, TV or $TM new Prius? I'm going with Prius.",positive
#
# Tokens
# ['"Which', 'is', 'more', 'interesting', 'unveil', 'tomorrow?', '$AAPL', '6s,', 'Ipad,', 'TV', 'or', '$TM', 'new', 'Prius?', "I'm", 'going', 'with', 'Prius.",positive']
# record
# "To prepare for the #AppleEvent tomorrow I am reminiscing over legacy apple hardware including iPod 2nd Gen, iPhone 4, iPad 2. Get Pumped!",positive
#
# Tokens
# ['"To', 'prepare', 'for', 'the', '#AppleEvent', 'tomorrow', 'I', 'am', 'reminiscing', 'over', 'legacy', 'apple', 'hardware', 'including', 'iPod', '2nd', 'Gen,', 'iPhone', '4,', 'iPad', '2.', 'Get', 'Pumped!",positive']
# record
# "Sundays vlog is processing, Monday's is exporting... You know for having to do it all on a iPad is say I'm doing pretty good.",positive
#
# Tokens
# ...
#
# Tokens
# ['@mattoak', 'I', 'still', 'say', "it's", 'Monday', 'after', 'Zlatan', 'finishes', 'game', 'on', 'Sunday...', "They're", 'just', 'prepping.', "They'll", 'tease', 'enough', 'to', 'gather', 'the', 'media.,neutral']
# record
# Zlatan is a doubt for Friday's game at Lille with sprained ligaments in his knee. He had to be strapped up during the game last night. #PSG,neutral
#
# Tokens
# ['Zlatan', 'is', 'a', 'doubt', 'for', "Friday's", 'game', 'at', 'Lille', 'with', 'sprained', 'ligaments', 'in', 'his', 'knee.', 'He', 'had', 'to', 'be', 'strapped', 'up', 'during', 'the', 'game', 'last', 'night.', '#PSG,neutral']
# record
# @JenniferWegerup Hey Jennifer. What is your source for your article about Zlatan will be in Istanbul on the 6th of aug. Thanks a lot.,neutral
#
# Tokens
# ['@JenniferWegerup', 'Hey', 'Jennifer.', 'What', 'is', 'your', 'source', 'for', 'your', 'article', 'about', 'Zlatan', 'will', 'be', 'in', 'Istanbul', 'on', 'the', '6th', 'of', 'aug.', 'Thanks', 'a', 'lot.,neutral']
# record
# @_mindy_ @RetroUnited coz of Zlatan talking how he loves a fight. May make him show LVG just how he is truly world class.,neutral
#
# Tokens
# ['@_mindy_', '@RetroUnited', 'coz', 'of', 'Zlatan', 'talking', 'how', 'he', 'loves', 'a', 'fight.', 'May', 'make', 'him', 'show', 'LVG', 'just', 'how', 'he', 'is', 'truly', 'world', 'class.,neutral']
# record
# "Orun ni zlatan sun niyen smh""@ZIatanFacts: Zlatan once went to a movie, and it watched him for two hours. #ZlatanFacts""",positive
#
# Tokens
# ['"Orun', 'ni', 'zlatan', 'sun', 'niyen', 'smh""@ZIatanFacts:', 'Zlatan', 'once', 'went', 'to', 'a', 'movie,', 'and', 'it', 'watched', 'him', 'for', 'two', 'hours.', '#ZlatanFacts""",positive']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# "Ibra recovery time is still unknown, the French League starts on Friday. PSG will play Lille, Zlatan is very much in doubt for that.",neutral
#
# Tokens
# ['"Ibra', 'recovery', 'time', 'is', 'still', 'unknown,', 'the', 'French', 'League', 'starts', 'on', 'Friday.', 'PSG', 'will', 'play', 'Lille,', 'Zlatan', 'is', 'very', 'much', 'in', 'doubt', 'for', 'that.",neutral']
# record
# "@MinoRaiola just because your hunger for more money Zlatan will play in a team that finished at the 10th place and struggle for top 5,shame",negative
#
# Tokens
# ['"@MinoRaiola', 'just', 'because', 'your', 'hunger', 'for', 'more', 'money', 'Zlatan', 'will', 'play', 'in', 'a', 'team', 'that', 'finished', 'at', 'the', '10th', 'place', 'and', 'struggle', 'for', 'top', '5,shame",negative']
# record
# Zlatan says he may have played his last match for PSG. Get him over here NOW: https://t.co/E9EL2zv21c,positive
#
# Tokens
# ['Zlatan', 'says', 'he', 'may', 'have', 'played', 'his', 'last', 'match', 'for', 'PSG.', 'Get', 'him', 'over', 'here', 'NOW:', 'https://t.co/E9EL2zv21c,positive']
# record
# "Think Laurent Blanc may be the man to beat this season...Zlatan flanked by Di Maria &amp; Lucas,  Verratti, Motta &amp; Pastore/Matuidi in midfield",positive
#
# Tokens
# ['"Think', 'Laurent', 'Blanc', 'may', 'be', 'the', 'man', 'to', 'beat', 'this', 'season...Zlatan', 'flanked', 'by', 'Di', 'Maria', '&amp;', 'Lucas,', 'Verratti,', 'Motta', '&amp;', 'Pastore/Matuidi', 'in', 'midfield",positive']
# record
# Flying to Paris tomorrow morning! First on the agenda is have a croissant and some frog's legs with Zlatan on the Eiffel tower.,positive
#
# Tokens
# ['Flying', 'to', 'Paris', 'tomorrow', 'morning!', 'First', 'on', 'the', 'agenda', 'is', 'have', 'a', 'croissant', 'and', 'some', "frog's", 'legs', 'with', 'Zlatan', 'on', 'the', 'Eiffel', 'tower.,positive']
# record
# Zlatan Ibrahimovich. @zlatan_ibra9 Gracious LeBron James Images. You may want to check: http://t.co/IZJni9WhTB,positive
#
# Tokens
# ['Zlatan', 'Ibrahimovich.', '@zlatan_ibra9', 'Gracious', 'LeBron', 'James', 'Images.', 'You', 'may', 'want', 'to', 'check:', 'http://t.co/IZJni9WhTB,positive']
# record
# "@DivinityHope Sure, someone who scored more goals than Zlatan and Edinson would be 4th string lol you retard",neutral
#
# Tokens
# ['"@DivinityHope', 'Sure,', 'someone', 'who', 'scored', 'more', 'goals', 'than', 'Zlatan', 'and', 'Edinson', 'would', 'be', '4th', 'string', 'lol', 'you', 'retard",neutral']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# @MilanEye I didn't buy your club to invest in Zlatan. I shall visit China tomorrow &amp; gift you a china-made zlaCHAN  8) #Taekwondo #staycalm,neutral
#
# Tokens
# ['@MilanEye', 'I', "didn't", 'buy', 'your', 'club', 'to', 'invest', 'in', 'Zlatan.', 'I', 'shall', 'visit', 'China', 'tomorrow', '&amp;', 'gift', 'you', 'a', 'china-made', 'zlaCHAN', '8)', '#Taekwondo', '#staycalm,neutral']
# record
# "@MrTransferNewss @FootbaIISources considering I'm 31st, it looks like Zlatan's about to disappear.",neutral
#
# Tokens
# ['"@MrTransferNewss', '@FootbaIISources', 'considering', "I'm", '31st,', 'it', 'looks', 'like', "Zlatan's", 'about', 'to', 'disappear.",neutral']
# record
# Category,Tweet
#
# Tokens
# ['Category,Tweet']
# record
# Zlatan's 20th goal of the season not enough for who concede twice late on to draw 2-2 with Caen...,neutral
#
# Tokens
# ["Zlatan's", '20th', 'goal', 'of', 'the', 'season', 'not', 'enough', 'for', 'who', 'concede', 'twice', 'late', 'on', 'to', 'draw', '2-2', 'with', 'Caen...,neutral']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# "Scenes when Benzema walks out of tunnel tomorrow along with higuain , m'vila , Zlatan , Pele and Maradona. Lets smash hammers !! #COYG",positive
#
# Tokens
# ['"Scenes', 'when', 'Benzema', 'walks', 'out', 'of', 'tunnel', 'tomorrow', 'along', 'with', 'higuain', ',', "m'vila", ',', 'Zlatan', ',', 'Pele', 'and', 'Maradona.', 'Lets', 'smash', 'hammers', '!!', '#COYG",positive']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# @nananavy That &amp; Zlatan insisting on playing through pain for the 2nd half vs. Lyon. Why not just come off? 2-0 up anyway.,neutral
#
# Tokens
# ['@nananavy', 'That', '&amp;', 'Zlatan', 'insisting', 'on', 'playing', 'through', 'pain', 'for', 'the', '2nd', 'half', 'vs.', 'Lyon.', 'Why', 'not', 'just', 'come', 'off?', '2-0', 'up', 'anyway.,neutral']
# record
# Watching a replay of the PSG / Lille match from Friday. No Zlatan makes PSG unwatchable.,negative
#
# Tokens
# ['Watching', 'a', 'replay', 'of', 'the', 'PSG', '/', 'Lille', 'match', 'from', 'Friday.', 'No', 'Zlatan', 'makes', 'PSG', 'unwatchable.,negative']
# record
# @Jon_LeGossip Any truth to Galatasaray having made an informal offer to PSG for Zlatan? Is he fit to play this Sunday?,neutral
#
# Tokens
# ['@Jon_LeGossip', 'Any', 'truth', 'to', 'Galatasaray', 'having', 'made', 'an', 'informal', 'offer', 'to', 'PSG', 'for', 'Zlatan?', 'Is', 'he', 'fit', 'to', 'play', 'this', 'Sunday?,neutral']
# record
# @Paulkurth that 3rd shot looks like its from a Michael Bay movie. Zlatan just revealed himself to be Optimus prime.,neutral
#
# Tokens
# ['@Paulkurth', 'that', '3rd', 'shot', 'looks', 'like', 'its', 'from', 'a', 'Michael', 'Bay', 'movie.', 'Zlatan', 'just', 'revealed', 'himself', 'to', 'be', 'Optimus', 'prime.,neutral']
# record
# "@ACMilanNorway anyway, telling Zlatan he'll be the center of the team is like telling the sun it's the center of the solar system. No crap.",negative
#
# Tokens
# ['"@ACMilanNorway', 'anyway,', 'telling', 'Zlatan', "he'll", 'be', 'the', 'center', 'of', 'the', 'team', 'is', 'like', 'telling', 'the', 'sun', "it's", 'the', 'center', 'of', 'the', 'solar', 'system.', 'No', 'crap.",negative']
# record
# 7 more days till we start the campaign that will win us our 19th scudetto ! Zlatan or no Zlatan that trophy is ours. #ForzaMilan,positive
#
# Tokens
# ['7', 'more', 'days', 'till', 'we', 'start', 'the', 'campaign', 'that', 'will', 'win', 'us', 'our', '19th', 'scudetto', '!', 'Zlatan', 'or', 'no', 'Zlatan', 'that', 'trophy', 'is', 'ours.', '#ForzaMilan,positive']
# record
# The VP of France's refereeing union Laurent Ugo has said he accepts Zlatan's apology following the striker's rant at officials on Sunday.,positive
#
# Tokens
# ['The', 'VP', 'of', "France's", 'refereeing', 'union', 'Laurent', 'Ugo', 'has', 'said', 'he', 'accepts', "Zlatan's", 'apology', 'following', 'the', "striker's", 'rant', 'at', 'officials', 'on', 'Sunday.,positive']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# "OH NO, we supposedly pull out of Pedro deal as Zlatan becomes available. Please god I'll go church every Sunday if u make this not happen",neutral
#
# Tokens
# ['"OH', 'NO,', 'we', 'supposedly', 'pull', 'out', 'of', 'Pedro', 'deal', 'as', 'Zlatan', 'becomes', 'available.', 'Please', 'god', "I'll", 'go', 'church', 'every', 'Sunday', 'if', 'u', 'make', 'this', 'not', 'happen",neutral']
# record
# "Zlatan , will your perfumes make me perform overhead kicks .&lt;3 https://t.co/q9tVV95mlr",positive
#
# Tokens
# ['"Zlatan', ',', 'will', 'your', 'perfumes', 'make', 'me', 'perform', 'overhead', 'kicks', '.&lt;3', 'https://t.co/q9tVV95mlr",positive']
# record
# Sun are so full of shit they say PSG trying to replace Zlatan with Neymar hahaha,neutral
#
# Tokens
# ['Sun', 'are', 'so', 'full', 'of', 'shit', 'they', 'say', 'PSG', 'trying', 'to', 'replace', 'Zlatan', 'with', 'Neymar', 'hahaha,neutral']
# record
# Reserving the right to put Milan 3rd if Zlatan arrives,positive
#
# Tokens
# ['Reserving', 'the', 'right', 'to', 'put', 'Milan', '3rd', 'if', 'Zlatan', 'arrives,positive']
# record
# Zlatan is simply saving himself for the 2nd leg,positive
#
# Tokens
# ['Zlatan', 'is', 'simply', 'saving', 'himself', 'for', 'the', '2nd', 'leg,positive']
# record
# "@DaveEllis11 @klavierstuk but if Zlatan is available for a reasonable fee, it may well be worth going for, for an immediate solution.",positive
#
# Tokens
# ['"@DaveEllis11', '@klavierstuk', 'but', 'if', 'Zlatan', 'is', 'available', 'for', 'a', 'reasonable', 'fee,', 'it', 'may', 'well', 'be', 'worth', 'going', 'for,', 'for', 'an', 'immediate', 'solution.",positive']
# record
# @LiLHammy97 we may have the slimmest of chances cuz of De Gea. But not enough time rather try for Griezmann. Wont mind Zlatan for a year !,neutral
#
# Tokens
# ['@LiLHammy97', 'we', 'may', 'have', 'the', 'slimmest', 'of', 'chances', 'cuz', 'of', 'De', 'Gea.', 'But', 'not', 'enough', 'time', 'rather', 'try', 'for', 'Griezmann.', 'Wont', 'mind', 'Zlatan', 'for', 'a', 'year', '!,neutral']
# record
# The top 4 strikers in the world are not for sale and our coach can't handle the 5th (Zlatan),negative
#
# Tokens
# ['The', 'top', '4', 'strikers', 'in', 'the', 'world', 'are', 'not', 'for', 'sale', 'and', 'our', 'coach', "can't", 'handle', 'the', '5th', '(Zlatan),negative']
# record
# I would love to have cavani man. He's over shawdowed and played 2nd fiddle to Zlatan he would shine at arsenal,positive
#
# Tokens
# ['I', 'would', 'love', 'to', 'have', 'cavani', 'man.', "He's", 'over', 'shawdowed', 'and', 'played', '2nd', 'fiddle', 'to', 'Zlatan', 'he', 'would', 'shine', 'at', 'arsenal,positive']
# record
# @Jon_LeGossip I didn't think they will sell either. Maybe Rabiot but surely Cavani doesn't want to play 2nd fiddle to Zlatan anymore,neutral
#
# Tokens
# ['@Jon_LeGossip', 'I', "didn't", 'think', 'they', 'will', 'sell', 'either.', 'Maybe', 'Rabiot', 'but', 'surely', 'Cavani', "doesn't", 'want', 'to', 'play', '2nd', 'fiddle', 'to', 'Zlatan', 'anymore,neutral']
# record
# "Mourinho, Zlatan, Serie A - who are the winners and losers from the CL draw?: Thursday's ceremony in ... http://t.co/nnVgvDwUvk #RETWEET",positive
#
# Tokens
# ['"Mourinho,', 'Zlatan,', 'Serie', 'A', '-', 'who', 'are', 'the', 'winners', 'and', 'losers', 'from', 'the', 'CL', 'draw?:', "Thursday's", 'ceremony', 'in', '...', 'http://t.co/nnVgvDwUvk', '#RETWEET",positive']
# record
# Not Available,neutral
#
# Tokens
# ['Not', 'Available,neutral']
# record
# Zlatan wears sunglasses so his eyes do not harm the sun.,positive
#
# Tokens
# ['Zlatan', 'wears', 'sunglasses', 'so', 'his', 'eyes', 'do', 'not', 'harm', 'the', 'sun.,positive']
# record
# "@Keith_Russell I don't want it to be but it may be Austin. Obviously prefer Zlatan, muller, Lewandowski etc #mufc",neutral
#
# Tokens
# ['"@Keith_Russell', 'I', "don't", 'want', 'it', 'to', 'be', 'but', 'it', 'may', 'be', 'Austin.', 'Obviously', 'prefer', 'Zlatan,', 'muller,', 'Lewandowski', 'etc', '#mufc",neutral']
# record
# We held talks with PSG on Thursday for Zlatan name now confirmed to me but this is two days old news,neutral
#
# Tokens
# ['We', 'held', 'talks', 'with', 'PSG', 'on', 'Thursday', 'for', 'Zlatan', 'name', 'now', 'confirmed', 'to', 'me', 'but', 'this', 'is', 'two', 'days', 'old', 'news,neutral']
# record
# Not Available,positive
#
# Tokens
# ['Not', 'Available,positive']
# record
# "Zlatan is looking mighty attractive at the moment,if LVG doesn't get a striker by Tuesday, I really don't fancy us scoring goals this season",neutral
#
# Tokens
# ['"Zlatan', 'is', 'looking', 'mighty', 'attractive', 'at', 'the', 'moment,if', 'LVG', "doesn't", 'get', 'a', 'striker', 'by', 'Tuesday,', 'I', 'really', "don't", 'fancy', 'us', 'scoring', 'goals', 'this', 'season",neutral']
# record
# "Wonder if Zlatan will be a United player come Tuesday night, think he may be the only realistic option of a big name signing.",positive
#
# Tokens
# ['"Wonder', 'if', 'Zlatan', 'will', 'be', 'a', 'United', 'player', 'come', 'Tuesday', 'night,', 'think', 'he', 'may', 'be', 'the', 'only', 'realistic', 'option', 'of', 'a', 'big', 'name', 'signing.",positive']
# record
# "Today United should have done better, the referee didn't help at all!!!!  Rooney to 10 pls! Just sign Zlatan tomorrow pleeeeeeze",negative
#
# Tokens
# ['"Today', 'United', 'should', 'have', 'done', 'better,', 'the', 'referee', "didn't", 'help', 'at', 'all!!!!', 'Rooney', 'to', '10', 'pls!', 'Just', 'sign', 'Zlatan', 'tomorrow', 'pleeeeeeze",negative']
# record
# If there is a silver lining this shows LVG if we dont buy anyone b4 Tuesday we is fucked!! Fuck it i would take Zlatan!!,negative
#
# Tokens
# ['If', 'there', 'is', 'a', 'silver', 'lining', 'this', 'shows', 'LVG', 'if', 'we', 'dont', 'buy', 'anyone', 'b4', 'Tuesday', 'we', 'is', 'fucked!!', 'Fuck', 'it', 'i', 'would', 'take', 'Zlatan!!,negative']
# record
# If Wenger is in Paris. Could it be for Cavani or Zlatan?Then again he may be on a family break.,neutral
#
# Tokens
# ['If', 'Wenger', 'is', 'in', 'Paris.', 'Could', 'it', 'be', 'for', 'Cavani', 'or', 'Zlatan?Then', 'again', 'he', 'may', 'be', 'on', 'a', 'family', 'break.,neutral']
# record
# "Ok ed let's do this, Zlatan, greizmann and Laporte tomorrow make it happen",positive
#
# Tokens
# ['"Ok', 'ed', "let's", 'do', 'this,', 'Zlatan,', 'greizmann', 'and', 'Laporte', 'tomorrow', 'make', 'it', 'happen",positive']
# record
# Goal level: Zlatan  90k by Friday? = Posting every other day  #DSGS (Vine by @ElexAuerbach) https://t.co/BPUM3A8tSD,neutral
#
# Tokens
# ['Goal', 'level:', 'Zlatan', '90k', 'by', 'Friday?', '=', 'Posting', 'every', 'other', 'day', '#DSGS', '(Vine', 'by', '@ElexAuerbach)', 'https://t.co/BPUM3A8tSD,neutral']
# record
# @YouAreMyArsenal Wouldn't surprise me if we enquired.He can't be 100% happy playing 2nd fiddle to Zlatan but he's not worth PSG asking price,neutral
#
# Tokens
# ['@YouAreMyArsenal', "Wouldn't", 'surprise', 'me', 'if', 'we', 'enquired.He', "can't", 'be', '100%', 'happy', 'playing', '2nd', 'fiddle', 'to', 'Zlatan', 'but', "he's", 'not', 'worth', 'PSG', 'asking', 'price,neutral']
# record
# Rib injury for Zlatan against Russia is a big blow if he misses Austria game Tuesday. A chance for new Sunderland striker Toivonen #SAFC,neutral
#
# Tokens
# ['Rib', 'injury', 'for', 'Zlatan', 'against', 'Russia', 'is', 'a', 'big', 'blow', 'if', 'he', 'misses', 'Austria', 'game', 'Tuesday.', 'A', 'chance', 'for', 'new', 'Sunderland', 'striker', 'Toivonen', '#SAFC,neutral']
# record
# "Noooooo! I was hoping to see Zlatan being Zlatan in Tuesday! Oh well, still looking forward to the match.  https://t.co/swGyd9cQAJ",neutral
#
# Tokens
# ['"Noooooo!', 'I', 'was', 'hoping', 'to', 'see', 'Zlatan', 'being', 'Zlatan', 'in', 'Tuesday!', 'Oh', 'well,', 'still', 'looking', 'forward', 'to', 'the', 'match.', 'https://t.co/swGyd9cQAJ",neutral']

# %%
lex_file = open("AFINN-111.csv")

# %%
lexicons = {}
records = lex_file.readlines()
for record in records:
    #print(record) # line contains newline charecter
    #print(record.rstrip('\n').split(",")) - to remove new line charecter
    lexicons[record.rstrip('\n').split(",")[0]] = int(record.rstrip('\n').split(",")[1])
#print(lexicons)
#lexicons["abandon"]

# %%
#For each tweet
#For each word in tweet
#Get the word score (score is a numbe rif the word is in Lexicon, 0 if not)
#Add all the scores and find the ploarity
strength = []
for tweet in word_list:
    score = 0
    for word in tweet:
        if word in (lexicons):
            score = score + lexicons[word]
    strength.append(score)
#print(strength)

# %%
strength = []
for tweet in word_list:
    score = 0
    for word in tweet:
        if word in (lexicons):
            score = score + lexicons[word]
    strength.append(score)
#print(strength)

# %% [markdown]
# <a href="https://colab.research.google.com/github/hpsuresh12345/Python-code/blob/master/Identifying_common_columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings # Ignores any warning
warnings.filterwarnings("ignore")

df1= pd.read_csv("data11.csv",sep=',') 
df2 = pd.read_csv("data22.csv",sep=',')

# %%
df1
# Out:
#            Number
# 0        1339343X
# 1        1335572X
# 2        1346682X
# 3        1346681X
# 4        1783804X
# 5        1783810X
# 6        1308590X
# 7        1308592X
# 8        1783203X
# 9        1783121X
# 10       1980022X
# 11       1309744X
# 12      1308592X
# 13       1308597X
# 14       1309741X
# 15       2026263X
# 16       1156074X
# 17       1309743X
# 18       1309742X
# 19       1773212X
# 20       1524296X
# 21       2347120X
# 22       2329071X
# 23       2531664X
# 24       2005844X
# 25       1301471X
# 26       1154626X
# 27       1524284X
# 28       1506799X
# 29       1611083X
# ...           ...
# 3094     2387943X
# 3095     2387952X
# 3096     2093352X
# 3097     1606917X
# 3098     1607661X
# 3099     1900227X
# 3100     1900592X
# 3101  2008704X-01
# 3102   E4062614BR
# 3103     E4074537
# 3104     2168865X
# 3105     2383043X
# 3106     2170481X
# 3107     1613870X
# 3108     1587589X
# 3109     1729763X
# 3110     2339190X
# 3111     2339262X
# ...

# %%
df2
# Out:
#        Number  Unnamed: 1  Unnamed: 2
# 0    1339343X         NaN         NaN
# 1    1335572X         NaN         NaN
# 2    1308590X         NaN         NaN
# 3    1308592X         NaN         NaN
# 4    1980022X         NaN         NaN
# 5    1309744X         NaN         NaN
# 6    1308597X         NaN         NaN
# 7    1309741X         NaN         NaN
# 8    1309743X         NaN         NaN
# 9    1309742X         NaN         NaN
# 10   2329071X         NaN         NaN
# 11   2531664X         NaN         NaN
# 12   2044834X         NaN         NaN
# 13   2454041X         NaN         NaN
# 14   1242311X         NaN         NaN
# 15   2483576X         NaN         NaN
# 16   2483577X         NaN         NaN
# 17   2458950X         NaN         NaN
# 18   2275018X         NaN         NaN
# 19   2275019X         NaN         NaN
# 20   2204735X         NaN         NaN
# 21   2204736X         NaN         NaN
# 22   2329146X         NaN         NaN
# 23   2182399X         NaN         NaN
# ...

# %%
df = pd.merge(df1, df2, how='inner', on=['Number'])

# %%
df.to_csv('df.csv', index=False)
